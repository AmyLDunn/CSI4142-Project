# %%
import pandas as pd

# %%
import json
from pandas import json_normalize

# %%
df = pd.read_csv("../raw_data/fire-station-locations.csv")

# %%
display(df)
# Out:
#     _id  ADDRESS_POINT_ID  ADDRESS_NUMBER LINEAR_NAME_FULL            ADDRESS  \
# 0     1           4236992             900      Tapscott Rd    900 Tapscott Rd
# 1     2            308265             351    Birchmount Rd  351 Birchmount Rd
# 2     3            764237             106        Ascot Ave      106 Ascot Ave
# 3     4            819425              65     Hendrick Ave    65 Hendrick Ave
# 4     5          12763904             260    Adelaide St W  260 Adelaide St W
# ..  ...               ...             ...              ...                ...
# 87   88          30013624            4100         Keele St      4100 Keele St
# 88   89            998837             130        Eighth St      130 Eighth St
# 89   90           2820826            1550      Midland Ave   1550 Midland Ave
# 90   91           8292449              59        Curlew Dr       59 Curlew Dr
# 91   92           3890947             231         McRae Dr       231 McRae Dr
#
#    MUNICIPALITY_NAME  CENTRELINE_ID  OBJECTID  ID  STATION  YEAR_BUILD  WARD  \
# 0        Scarborough        4236991   1520443   2    211.0      1982.0    23
# 1        Scarborough         112783   1527311  69      NaN      1925.0    20
# 2     former Toronto        1140634   1541526  37    342.0      1915.0     9
# 3     former Toronto        1140587   1543317  36    343.0      1962.0    12
# 4     former Toronto       12763900   1558261  85    332.0      1971.0    10
# ..               ...            ...       ...  ..      ...         ...   ...
# 87        North York       30020840   4350759  77    141.0      2011.0     7
# 88         Etobicoke       30118412   4352480  23    435.0      1920.0     3
# 89       Scarborough       30122712   4393085  58    232.0      1963.0    21
# 90        North York        8292440   4395143  92    233.0      1995.0    16
# 91         East York        3890945   4400109  87    321.0      1946.0    15
#
#                    WARD_NAME     TYPE_DESC         PUBLIC_ED_OFFICE  \
# 0          Scarborough North  Fire Station                     None
# 1      Scarborough Southwest         Admin                     None
# 2                  Davenport  Fire Station                     None
# 3         Toronto-St. Paul's  Fire Station                     None
# 4          Spadina-Fort York  Fire Station                     None
# ..                       ...           ...                      ...
# 87  Humber River-Black Creek  Fire Station                     None
# 88       Etobicoke-Lakeshore  Fire Station                     None
# 89        Scarborough Centre  Fire Station                     None
# 90           Don Valley East  Fire Station  Public Education Museum
# 91           Don Valley West  Fire Station                     None
#
#               FIRE_PREV_OFFICE  \
# 0                         None
# 1   Fire Prevention Office (E)
# 2                         None
# 3                         None
# 4   Fire Prevention Office (S)
# ..                         ...
# 87  Fire Prevention Office (N)
# 88                        None
# 89                        None
# 90      Fire Prevention Office
# 91  Fire Prevention Office (N)
#
#                                            FIRE_OTHER  \
# 0                                                None
# 1                                         Fire Museum
# 2                                                None
# 3                                                None
# 4                 Division Commander / Platoon Chiefs
# ..                                                ...
# 87                                               None
# 88                                               None
# 89                                               None
# 90  FP Special Event Plans and Projects / Quality ...
# 91                                               None
#
#                                              geometry
# 0   {'type': 'Point', 'coordinates': (-79.24287003...
# 1   {'type': 'Point', 'coordinates': (-79.26480700...
# 2   {'type': 'Point', 'coordinates': (-79.44862626...
# 3   {'type': 'Point', 'coordinates': (-79.43075215...
# 4   {'type': 'Point', 'coordinates': (-79.38956419...
# ..                                                ...
# 87  {'type': 'Point', 'coordinates': (-79.49272359...
# 88  {'type': 'Point', 'coordinates': (-79.50696999...
# 89  {'type': 'Point', 'coordinates': (-79.26685107...
# 90  {'type': 'Point', 'coordinates': (-79.31438279...
# 91  {'type': 'Point', 'coordinates': (-79.36469829...
#
# [92 rows x 18 columns]

# %%
b = df["geometry"][0]

b = b.replace("\'", "\"")
b= b.replace("(", "[")
b= b.replace(")", "]")

# b = '{"type": "Point", "coordinates": [-79.2428700353868, 43.8239927252015]}'

c = json.loads(b)
print(c)
print(type(c))
# Out:
# {'type': 'Point', 'coordinates': [-79.2428700353868, 43.8239927252015]}
# <class 'dict'>

# %%
df['geometry'] = df['geometry'].apply(lambda x: x.replace("\'", "\""))

# %%
df['geometry'] = df['geometry'].apply(lambda x: x.replace("(", "["))

# %%
df['geometry'] = df['geometry'].apply(lambda x: x.replace(")", "]"))

# %%
df['geometry'] = df['geometry'].apply(lambda x: json.loads(x))

# %%
print(df['geometry'])
# Out:
# 0     {'type': 'Point', 'coordinates': [-79.24287003...
# 1     {'type': 'Point', 'coordinates': [-79.26480700...
# 2     {'type': 'Point', 'coordinates': [-79.44862626...
# 3     {'type': 'Point', 'coordinates': [-79.43075215...
# 4     {'type': 'Point', 'coordinates': [-79.38956419...
#                             ...
# 87    {'type': 'Point', 'coordinates': [-79.49272359...
# 88    {'type': 'Point', 'coordinates': [-79.50696999...
# 89    {'type': 'Point', 'coordinates': [-79.26685107...
# 90    {'type': 'Point', 'coordinates': [-79.31438279...
# 91    {'type': 'Point', 'coordinates': [-79.36469829...
# Name: geometry, Length: 92, dtype: object

# %%
dfLat = df['geometry'].map(lambda x: x['coordinates'][0])

# %%
dfLong = df['geometry'].map(lambda x: x['coordinates'][1])

# %%
display(dfLong)
# Out:
# 0     43.823993
# 1     43.699878
# 2     43.679366
# 3     43.680105
# 4     43.648307
#         ...
# 87    43.766822
# 88    43.601119
# 89    43.754967
# 90    43.743918
# 91    43.708714
# Name: geometry, Length: 92, dtype: float64

# %%
df2=df.merge(dfLat.rename('Latitude'), left_index=True, right_index=True)

# %%
df2 = df2.merge(dfLong.rename('Longitude'), left_index=True, right_index=True)

# %%
df2 = df2.drop(columns=['_id','ADDRESS_POINT_ID','ADDRESS_NUMBER','LINEAR_NAME_FULL','CENTRELINE_ID','OBJECTID','YEAR_BUILD','PUBLIC_ED_OFFICE','FIRE_PREV_OFFICE','FIRE_OTHER', 'geometry'])

# %%
display(df2)
# Out:
#               ADDRESS MUNICIPALITY_NAME  ID  STATION  WARD  \
# 0     900 Tapscott Rd       Scarborough   2    211.0    23
# 1   351 Birchmount Rd       Scarborough  69      NaN    20
# 2       106 Ascot Ave    former Toronto  37    342.0     9
# 3     65 Hendrick Ave    former Toronto  36    343.0    12
# 4   260 Adelaide St W    former Toronto  85    332.0    10
# ..                ...               ...  ..      ...   ...
# 87      4100 Keele St        North York  77    141.0     7
# 88      130 Eighth St         Etobicoke  23    435.0     3
# 89   1550 Midland Ave       Scarborough  58    232.0    21
# 90       59 Curlew Dr        North York  92    233.0    16
# 91       231 McRae Dr         East York  87    321.0    15
#
#                    WARD_NAME     TYPE_DESC   Latitude  Longitude
# 0          Scarborough North  Fire Station -79.242870  43.823993
# 1      Scarborough Southwest         Admin -79.264807  43.699878
# 2                  Davenport  Fire Station -79.448626  43.679366
# 3         Toronto-St. Paul's  Fire Station -79.430752  43.680105
# 4          Spadina-Fort York  Fire Station -79.389564  43.648307
# ..                       ...           ...        ...        ...
# 87  Humber River-Black Creek  Fire Station -79.492724  43.766822
# 88       Etobicoke-Lakeshore  Fire Station -79.506970  43.601119
# 89        Scarborough Centre  Fire Station -79.266851  43.754967
# 90           Don Valley East  Fire Station -79.314383  43.743918
# 91           Don Valley West  Fire Station -79.364698  43.708714
#
# [92 rows x 9 columns]

# %%
df2 = df2[df2["TYPE_DESC"] !="Admin"].reset_index()  #removes admin values, not a station and then numbers indexes correctly

# %%
display(df2)
# Out:
#     index            ADDRESS MUNICIPALITY_NAME  ID  STATION  WARD  \
# 0       0    900 Tapscott Rd       Scarborough   2    211.0    23
# 1       2      106 Ascot Ave    former Toronto  37    342.0     9
# 2       3    65 Hendrick Ave    former Toronto  36    343.0    12
# 3       4  260 Adelaide St W    former Toronto  85    332.0    10
# 4       5  745 Meadowvale Rd       Scarborough  68    214.0    25
# ..    ...                ...               ...  ..      ...   ...
# 81     87      4100 Keele St        North York  77    141.0     7
# 82     88      130 Eighth St         Etobicoke  23    435.0     3
# 83     89   1550 Midland Ave       Scarborough  58    232.0    21
# 84     90       59 Curlew Dr        North York  92    233.0    16
# 85     91       231 McRae Dr         East York  87    321.0    15
#
#                    WARD_NAME     TYPE_DESC   Latitude  Longitude
# 0          Scarborough North  Fire Station -79.242870  43.823993
# 1                  Davenport  Fire Station -79.448626  43.679366
# 2         Toronto-St. Paul's  Fire Station -79.430752  43.680105
# 3          Spadina-Fort York  Fire Station -79.389564  43.648307
# 4     Scarborough-Rouge Park  Fire Station -79.163602  43.794211
# ..                       ...           ...        ...        ...
# 81  Humber River-Black Creek  Fire Station -79.492724  43.766822
# 82       Etobicoke-Lakeshore  Fire Station -79.506970  43.601119
# 83        Scarborough Centre  Fire Station -79.266851  43.754967
# 84           Don Valley East  Fire Station -79.314383  43.743918
# 85           Don Valley West  Fire Station -79.364698  43.708714
#
# [86 rows x 10 columns]

# %%
unique = {}
stations = df2["WARD"]
for _, station in stations.items():
    added = False
    for wardNum in unique:
        if station == wardNum:
            unique[station] = unique[station]+1
            added = True
            
    if not added:
        unique[station] =1

print(unique)
print(len(unique))

total = 0
for wardNum in unique:
    total = total+unique[wardNum]
print(total)
# Out:
# {23: 4, 9: 2, 12: 3, 10: 5, 25: 3, 4: 4, 15: 4, 1: 4, 8: 3, 13: 4, 17: 3, 2: 4, 3: 5, 14: 4, 24: 2, 20: 4, 19: 3, 22: 2, 16: 4, 11: 3, 5: 3, 7: 4, 6: 3, 21: 3, 18: 3}
# 25
# 86

# %%
dfStation = pd.DataFrame.from_dict(unique, orient='index', columns=[ 'StationsInWard'])
display(dfStation.head())
# Out:
#     StationsInWard
# 23               4
# 9                2
# 12               3
# 10               5
# 25               3

# %%
dfStation = dfStation.reset_index()
display(dfStation.head())
# Out:
#    index  StationsInWard
# 0     23               4
# 1      9               2
# 2     12               3
# 3     10               5
# 4     25               3

# %%
dfStation = dfStation.rename(columns = {"index":"WardNumber"})
display(dfStation.head())
# Out:
#    WardNumber  StationsInWard
# 0          23               4
# 1           9               2
# 2          12               3
# 3          10               5
# 4          25               3

# %%
dfStation = dfStation.sort_values(by = ["WardNumber"])
display(dfStation.head())
# Out:
#     WardNumber  StationsInWard
# 7            1               4
# 11           2               4
# 12           3               5
# 5            4               4
# 20           5               3

# %%
dfStation.reset_index(inplace = True)
display(dfStation.head())
# Out:
#    index  WardNumber  StationsInWard
# 0      7           1               4
# 1     11           2               4
# 2     12           3               5
# 3      5           4               4
# 4     20           5               3

# %%
dfStation = dfStation.drop(columns = "index")
dfStation = dfStation.rename(columns={'WardNumber':'fire_ward_key','StationsInWard':'stations_in_ward'})
display(dfStation.head())
# Out:
#    fire_ward_key  stations_in_ward
# 0              1                 4
# 1              2                 4
# 2              3                 5
# 3              4                 4
# 4              5                 3

# %%
dfStation.to_csv("../raw_data/WardData.csv",  index = False)

# %%
#uncomment the following line of code if psycopg2 or sqlalchemy not installed locally
#!pip install psycopg2
#!pip install sqlalchemy
import psycopg2
import sqlalchemy

# %%
#Using postgres 13
#format: postgresql+psycopg2://username:password@host_address/database_name
engine = sqlalchemy.create_engine('postgresql+psycopg2://postgres:CSI4142@localhost:5432/fire_hazard')
dfStation.to_sql(name='dim_fire_ward', con=engine,if_exists='append', index=False)
# Out:
# 25
