# %%
import pandas as pd

# %%
#getting data from the preprocessed csv file for 2022
df_2021=pd.read_csv('../raw_data/census_2021.csv')
df_2021= df_2021.drop(columns = ['Unnamed: 0'])
df_2021
# Out:
#        demographics_key  dissemination_area  population  average_age  \
# 0          202135010159            35010159       533.0         45.8
# 1          202135010160            35010160       485.0         45.2
# 2          202135010161            35010161       402.0         44.5
# 3          202135010162            35010162       383.0         50.9
# 4          202135010163            35010163       519.0         45.1
# ...                 ...                 ...         ...          ...
# 20463      202135600224            35600224         NaN          NaN
# 20464      202135600237            35600237         NaN          NaN
# 20465      202135600256            35600256       511.0         30.3
# 20466      202135600218            35600218        16.0          NaN
# 20467      202135600238            35600238       409.0         24.1
#
#        median_age  total_dwellings  average_household_size  \
# 0            50.4            210.0                     2.6
# 1            50.0            200.0                     2.4
# 2            44.8            160.0                     2.5
# 3            57.2            150.0                     2.2
# 4            48.8            210.0                     2.4
# ...           ...              ...                     ...
# 20463         NaN              NaN                     NaN
# 20464         NaN              NaN                     NaN
# 20465        26.0            120.0                     4.3
# 20466         NaN              NaN                     NaN
# 20467        19.6             90.0                     4.4
#
#        median_household_income  mother_tongue_official_percentage  \
# 0                      87000.0                              95.28
# 1                      88000.0                              94.85
# 2                      77000.0                              96.25
# 3                      73500.0                              98.67
# 4                      84000.0                              94.17
# ...                        ...                                ...
# 20463                      NaN                                NaN
# 20464                      NaN                                NaN
# 20465                  81000.0                              32.00
# 20466                      NaN                                NaN
# 20467                  67500.0                              76.83
#
#        mother_tongue_unofficial_percentage  census_year
# 0                                     4.72         2021
# 1                                     5.15         2021
# 2                                     3.75         2021
# 3                                     1.33         2021
# 4                                     5.83         2021
# ...                                    ...          ...
# 20463                                  NaN         2021
# 20464                                  NaN         2021
# 20465                                68.00         2021
# 20466                                  NaN         2021
# 20467                                23.17         2021
#
# [20468 rows x 11 columns]

# %%
#getting the data fromt the preprocessed csv file for 2016
df_2016=pd.read_csv('../raw_data/census_2016.csv')
df_2016= df_2016.drop(columns = ['Unnamed: 0'])
df_2016.dissemination_area=df_2016.dissemination_area.astype('int64')
df_2016
# Out:
#        demographics_key  dissemination_area  population  average_age  \
# 0          2.016350e+11            35010159       517.0         45.9
# 1          2.016350e+11            35010160       509.0         43.5
# 2          2.016350e+11            35010161       388.0         43.7
# 3          2.016350e+11            35010162       376.0         52.7
# 4          2.016350e+11            35010163       501.0         43.9
# ...                 ...                 ...         ...          ...
# 20155      2.016356e+11            35600237       276.0         28.8
# 20156      2.016356e+11            35600256       511.0         29.1
# 20157      2.016356e+11            35600218        22.0          NaN
# 20158      2.016356e+11            35600241         0.0          NaN
# 20159      2.016356e+11            35600238       421.0         25.1
#
#        median_age  total_dwellings  average_household_size  \
# 0            52.5            210.0                     2.5
# 1            47.1            200.0                     2.6
# 2            48.2            150.0                     2.6
# 3            57.5            155.0                     2.2
# 4            47.5            205.0                     2.4
# ...           ...              ...                     ...
# 20155        24.2             85.0                     3.4
# 20156        25.9            100.0                     4.8
# 20157         NaN              NaN                     NaN
# 20158         NaN              NaN                     NaN
# 20159        21.4             85.0                     4.7
#
#        median_household_income  mother_tongue_official_percentage  \
# 0                      31659.0                             100.00
# 1                      32981.0                             100.00
# 2                      31040.0                              98.72
# 3                      29760.0                             100.00
# 4                      35200.0                             100.00
# ...                        ...                                ...
# 20155                  20736.0                              98.18
# 20156                  25664.0                              98.04
# 20157                      NaN                                NaN
# 20158                      NaN                                NaN
# 20159                  17744.0                              98.81
#
#        mother_tongue_unofficial_percentage  census_year
# 0                                     0.00       2016.0
# 1                                     0.00       2016.0
# 2                                     1.28       2016.0
# 3                                     0.00       2016.0
# 4                                     0.00       2016.0
# ...                                    ...          ...
# 20155                                 1.82       2016.0
# 20156                                 1.96       2016.0
# 20157                                  NaN       2016.0
# 20158                                  NaN       2016.0
# 20159                                 1.19       2016.0
#
# [20160 rows x 11 columns]

# %%
#getting the data fromt the preprocessed csv file for 2011
df_2011=pd.read_csv('../raw_data/census_2011.csv')
df_2011= df_2011.drop(columns = ['Unnamed: 0'])
df_2011
# Out:
#        demographics_key  dissemination_area  population  average_age  \
# 0          201135010155            35010155       486.0          NaN
# 1          201135010156            35010156       477.0          NaN
# 2          201135010157            35010157       501.0          NaN
# 3          201135010158            35010158       520.0          NaN
# 4          201135010159            35010159       502.0          NaN
# ...                 ...                 ...         ...          ...
# 19959      201135600399            35600399         0.0          NaN
# 19960      201135600400            35600400         0.0          NaN
# 19961      201135600401            35600401       483.0          NaN
# 19962      201135600402            35600402       556.0          NaN
# 19963      201135600403            35600403         0.0          NaN
#
#        median_age  total_dwellings  average_household_size  \
# 0            47.0            190.0                     2.6
# 1            45.7            200.0                     2.4
# 2            45.8            195.0                     2.6
# 3            46.9            210.0                     2.5
# 4            48.9            205.0                     2.5
# ...           ...              ...                     ...
# 19959         NaN              NaN                     NaN
# 19960         NaN              NaN                     NaN
# 19961        51.4            195.0                     2.5
# 19962         NaN              NaN                     NaN
# 19963         NaN              NaN                     NaN
#
#        median_household_income  mother_tongue_official_percentage  \
# 0                          NaN                             100.00
# 1                          NaN                             100.00
# 2                          NaN                             100.00
# 3                          NaN                             100.00
# 4                          NaN                              99.01
# ...                        ...                                ...
# 19959                      NaN                                NaN
# 19960                      NaN                                NaN
# 19961                      NaN                             100.00
# 19962                      NaN                                NaN
# 19963                      NaN                                NaN
#
#        mother_tongue_unofficial_percentage  census_year
# 0                                     0.00         2011
# 1                                     0.00         2011
# 2                                     0.00         2011
# 3                                     0.00         2011
# 4                                     0.99         2011
# ...                                    ...          ...
# 19959                                  NaN         2011
# 19960                                  NaN         2011
# 19961                                 0.00         2011
# 19962                                  NaN         2011
# 19963                                  NaN         2011
#
# [19964 rows x 11 columns]

# %%
#copy the median_household_income from the next year
df_2011= df_2011.drop(columns = ['median_household_income'])
df_2011=df_2011.merge(df_2016[['dissemination_area', 'median_household_income']], on = 'dissemination_area', how = 'left')
#reordering the rows to match the other dataframes

#list(df_2011)
df_2011=df_2011[['demographics_key', 'dissemination_area','population','average_age','median_age',
                'total_dwellings','average_household_size','median_household_income',
                'mother_tongue_official_percentage','mother_tongue_unofficial_percentage','census_year']]
df_2011
# Out:
#        demographics_key  dissemination_area  population  average_age  \
# 0          201135010155            35010155       486.0          NaN
# 1          201135010156            35010156       477.0          NaN
# 2          201135010157            35010157       501.0          NaN
# 3          201135010158            35010158       520.0          NaN
# 4          201135010159            35010159       502.0          NaN
# ...                 ...                 ...         ...          ...
# 19959      201135600399            35600399         0.0          NaN
# 19960      201135600400            35600400         0.0          NaN
# 19961      201135600401            35600401       483.0          NaN
# 19962      201135600402            35600402       556.0          NaN
# 19963      201135600403            35600403         0.0          NaN
#
#        median_age  total_dwellings  average_household_size  \
# 0            47.0            190.0                     2.6
# 1            45.7            200.0                     2.4
# 2            45.8            195.0                     2.6
# 3            46.9            210.0                     2.5
# 4            48.9            205.0                     2.5
# ...           ...              ...                     ...
# 19959         NaN              NaN                     NaN
# 19960         NaN              NaN                     NaN
# 19961        51.4            195.0                     2.5
# 19962         NaN              NaN                     NaN
# 19963         NaN              NaN                     NaN
#
#        median_household_income  mother_tongue_official_percentage  \
# 0                      27712.0                             100.00
# 1                      26688.0                             100.00
# 2                      31200.0                             100.00
# 3                      32384.0                             100.00
# 4                      31659.0                              99.01
# ...                        ...                                ...
# 19959                      NaN                                NaN
# 19960                      NaN                                NaN
# 19961                  39936.0                             100.00
# 19962                  31584.0                                NaN
# 19963                      NaN                                NaN
#
#        mother_tongue_unofficial_percentage  census_year
# 0                                     0.00         2011
# 1                                     0.00         2011
# 2                                     0.00         2011
# 3                                     0.00         2011
# 4                                     0.99         2011
# ...                                    ...          ...
# 19959                                  NaN         2011
# 19960                                  NaN         2011
# 19961                                 0.00         2011
# 19962                                  NaN         2011
# 19963                                  NaN         2011
#
# [19964 rows x 11 columns]

# %%
#combine the three census years together into one dataframe
frames = [df_2011, df_2016, df_2021]
result = pd.concat(frames)
result
# Out:
#        demographics_key  dissemination_area  population  average_age  \
# 0          2.011350e+11            35010155       486.0          NaN
# 1          2.011350e+11            35010156       477.0          NaN
# 2          2.011350e+11            35010157       501.0          NaN
# 3          2.011350e+11            35010158       520.0          NaN
# 4          2.011350e+11            35010159       502.0          NaN
# ...                 ...                 ...         ...          ...
# 20463      2.021356e+11            35600224         NaN          NaN
# 20464      2.021356e+11            35600237         NaN          NaN
# 20465      2.021356e+11            35600256       511.0         30.3
# 20466      2.021356e+11            35600218        16.0          NaN
# 20467      2.021356e+11            35600238       409.0         24.1
#
#        median_age  total_dwellings  average_household_size  \
# 0            47.0            190.0                     2.6
# 1            45.7            200.0                     2.4
# 2            45.8            195.0                     2.6
# 3            46.9            210.0                     2.5
# 4            48.9            205.0                     2.5
# ...           ...              ...                     ...
# 20463         NaN              NaN                     NaN
# 20464         NaN              NaN                     NaN
# 20465        26.0            120.0                     4.3
# 20466         NaN              NaN                     NaN
# 20467        19.6             90.0                     4.4
#
#        median_household_income  mother_tongue_official_percentage  \
# 0                      27712.0                             100.00
# 1                      26688.0                             100.00
# 2                      31200.0                             100.00
# 3                      32384.0                             100.00
# 4                      31659.0                              99.01
# ...                        ...                                ...
# 20463                      NaN                                NaN
# 20464                      NaN                                NaN
# 20465                  81000.0                              32.00
# 20466                      NaN                                NaN
# 20467                  67500.0                              76.83
#
#        mother_tongue_unofficial_percentage  census_year
# 0                                     0.00       2011.0
# 1                                     0.00       2011.0
# 2                                     0.00       2011.0
# 3                                     0.00       2011.0
# 4                                     0.99       2011.0
# ...                                    ...          ...
# 20463                                  NaN       2021.0
# 20464                                  NaN       2021.0
# 20465                                68.00       2021.0
# 20466                                  NaN       2021.0
# 20467                                23.17       2021.0
#
# [60592 rows x 11 columns]

# %%
#Removed the average age column as the average age was not reported in the 2011 or 2016 census profiles
result=result.drop(columns=['average_age'])
#removed the rows where the population or average_household_size was null
result=result.dropna(subset=['population','average_household_size','median_household_income',
                             'mother_tongue_official_percentage','mother_tongue_unofficial_percentage']).reset_index(drop = True) 
#convert demographics_key into an integer
result.demographics_key=result.demographics_key.astype('int64')


#convert population into an integer
result.population=result.population.astype('int64')
#convert date to an integer
result.census_year=result.census_year.astype('int64')
#convert total_dwellings to int
result.total_dwellings=result.total_dwellings.astype('int64')
#print the resulting table
result
# Out:
#        demographics_key  dissemination_area  population  median_age  \
# 0          201135010155            35010155         486        47.0
# 1          201135010156            35010156         477        45.7
# 2          201135010157            35010157         501        45.8
# 3          201135010158            35010158         520        46.9
# 4          201135010159            35010159         502        48.9
# ...                 ...                 ...         ...         ...
# 58332      202135600409            35600409         547        58.8
# 58333      202135600217            35600217         447        27.0
# 58334      202135600222            35600222        1060        22.4
# 58335      202135600256            35600256         511        26.0
# 58336      202135600238            35600238         409        19.6
#
#        total_dwellings  average_household_size  median_household_income  \
# 0                  190                     2.6                  27712.0
# 1                  200                     2.4                  26688.0
# 2                  195                     2.6                  31200.0
# 3                  210                     2.5                  32384.0
# 4                  205                     2.5                  31659.0
# ...                ...                     ...                      ...
# 58332              235                     2.2                  85000.0
# 58333              125                     3.6                  42800.0
# 58334              230                     4.6                  67000.0
# 58335              120                     4.3                  81000.0
# 58336               90                     4.4                  67500.0
#
#        mother_tongue_official_percentage  mother_tongue_unofficial_percentage  \
# 0                                 100.00                                 0.00
# 1                                 100.00                                 0.00
# 2                                 100.00                                 0.00
# 3                                 100.00                                 0.00
# 4                                  99.01                                 0.99
# ...                                  ...                                  ...
# 58332                              88.99                                11.01
# 58333                              64.44                                35.56
# 58334                              35.38                                64.62
# 58335                              32.00                                68.00
# 58336                              76.83                                23.17
#
#        census_year
# 0             2011
# 1             2011
# 2             2011
# 3             2011
# 4             2011
# ...            ...
# 58332         2021
# 58333         2021
# 58334         2021
# 58335         2021
# 58336         2021
#
# [58337 rows x 10 columns]

# %%
#uncomment the following line of code if psycopg2 or sqlalchemy not installed locally
#!pip install psycopg2
#!pip install sqlalchemy
import psycopg2
import sqlalchemy

# %%
#Using postgres 13
#format: postgresql+psycopg2://username:password@host_address/database_name
engine = sqlalchemy.create_engine('postgresql+psycopg2://postgres:CSI4142@localhost:5432/fire_hazard')
result.to_sql(name='dim_demographics', con=engine,if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# NumericValueOutOfRange                    Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_executemany(
#    1800                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     952             xtras = self._psycopg2_extras()
# --> 953             context._psycopg2_fetched_rows = xtras.execute_values(
#     954                 cursor,
#
# ~\anaconda3\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1298         parts[-1:] = post
# -> 1299         cur.execute(b''.join(parts))
#    1300         if fetch:
#
# NumericValueOutOfRange: integer out of range
#
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33024\1808406689.py in <module>
#       2 #format: postgresql+psycopg2://username:password@host_address/database_name
#       3 engine = sqlalchemy.create_engine('postgresql+psycopg2://postgres:CSI4142@localhost:5432/fire_hazard')
# ----> 4 result.to_sql(name='dim_demographics', con=engine,if_exists='append', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2949         from pandas.io import sql
#    2950
# -> 2951         return sql.to_sql(
#    2952             self,
#    2953             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     696         )
#     697
# --> 698     return pandas_sql.to_sql(
#     699         frame,
#     700         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1740         )
#    1741
# -> 1742         total_inserted = sql_engine.insert_records(
#    1743             table=table,
#    1744             con=self.connectable,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1333                 raise ValueError("inf cannot be used with MySQL") from err
#    1334             else:
# -> 1335                 raise err
#    1336
#    1337
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1323
#    1324         try:
# -> 1325             return table.insert(chunksize=chunksize, method=method)
#    1326         except exc.SQLAlchemyError as err:
#    1327             # GH34431
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     949
#     950                 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# --> 951                 num_inserted = exec_insert(conn, keys, chunk_iter)
#     952                 # GH 46891
#     953                 if is_integer(num_inserted):
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     856         """
#     857         data = [dict(zip(keys, row)) for row in data_iter]
# --> 858         result = conn.execute(self.table.insert(), data)
#     859         return result.rowcount
#     860
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1304             )
#    1305         else:
# -> 1306             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1307
#    1308     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     330     ):
#     331         if _force or self.supports_execution:
# --> 332             return connection._execute_clauseelement(
#     333                 self, multiparams, params, execution_options
#     334             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1496             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1497         )
# -> 1498         ret = self._execute_context(
#    1499             dialect,
#    1500             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1860
#    1861         except BaseException as e:
# -> 1862             self._handle_dbapi_exception(
#    1863                 e, statement, parameters, cursor, context
#    1864             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042             elif should_wrap:
# -> 2043                 util.raise_(
#    2044                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206
#     207         try:
# --> 208             raise exception
#     209         finally:
#     210             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1797                             break
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_executemany(
#    1800                         cursor, statement, parameters, context
#    1801                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     951                 kwargs = {}
#     952             xtras = self._psycopg2_extras()
# --> 953             context._psycopg2_fetched_rows = xtras.execute_values(
#     954                 cursor,
#     955                 statement,
#
# ~\anaconda3\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1297             parts.append(b',')
#    1298         parts[-1:] = post
# -> 1299         cur.execute(b''.join(parts))
#    1300         if fetch:
#    1301             result.extend(cur.fetchall())
#
# DataError: (psycopg2.errors.NumericValueOutOfRange) integer out of range
#
# [SQL: INSERT INTO dim_demographics (demographics_key, dissemination_area, population, median_age, total_dwellings, average_household_size, median_household_income, mother_tongue_official_percentage, mother_tongue_unofficial_percentage, census_year) VALUES (%(demographics_key)s, %(dissemination_area)s, %(population)s, %(median_age)s, %(total_dwellings)s, %(average_household_size)s, %(median_household_income)s, %(mother_tongue_official_percentage)s, %(mother_tongue_unofficial_percentage)s, %(census_year)s)]
# [parameters: ({'demographics_key': 201135010155, 'dissemination_area': 35010155, 'population': 486, 'median_age': 47.0, 'total_dwellings': 190, 'average_household_size': 2.6, 'median_household_income': 27712.0, 'mother_tongue_official_percentage': 100.0, 'mother_tongue_unofficial_percentage': 0.0, 'census_year': 2011}, {'demographics_key': 201135010156, 'dissemination_area': 35010156, 'population': 477, 'median_age': 45.7, 'total_dwellings': 200, 'average_household_size': 2.4, 'median_household_income': 26688.0, 'mother_tongue_official_percentage': 100.0, 'mother_tongue_unofficial_percentage': 0.0, 'census_year': 2011}, {'demographics_key': 201135010157, 'dissemination_area': 35010157, 'population': 501, 'median_age': 45.8, 'total_dwellings': 195, 'average_household_size': 2.6, 'median_household_income': 31200.0, 'mother_tongue_official_percentage': 100.0, 'mother_tongue_unofficial_percentage': 0.0, 'census_year': 2011}, {'demographics_key': 201135010158, 'dissemination_area': 35010158, 'population': 520, 'median_age': 46.9, 'total_dwellings': 210, 'average_household_size': 2.5, 'median_household_income': 32384.0, 'mother_tongue_official_percentage': 100.0, 'mother_tongue_unofficial_percentage': 0.0, 'census_year': 2011}, {'demographics_key': 201135010159, 'dissemination_area': 35010159, 'population': 502, 'median_age': 48.9, 'total_dwellings': 205, 'average_household_size': 2.5, 'median_household_income': 31659.0, 'mother_tongue_official_percentage': 99.01, 'mother_tongue_unofficial_percentage': 0.99, 'census_year': 2011}, {'demographics_key': 201135010160, 'dissemination_area': 35010160, 'population': 454, 'median_age': 44.5, 'total_dwellings': 180, 'average_household_size': 2.5, 'median_household_income': 32981.0, 'mother_tongue_official_percentage': 100.0, 'mother_tongue_unofficial_percentage': 0.0, 'census_year': 2011}, {'demographics_key': 201135010161, 'dissemination_area': 35010161, 'population': 414, 'median_age': 45.1, 'total_dwellings': 160, 'average_household_size': 2.6, 'median_household_income': 31040.0, 'mother_tongue_official_percentage': 100.0, 'mother_tongue_unofficial_percentage': 0.0, 'census_year': 2011}, {'demographics_key': 201135010162, 'dissemination_area': 35010162, 'population': 404, 'median_age': 52.0, 'total_dwellings': 155, 'average_household_size': 2.4, 'median_household_income': 29760.0, 'mother_tongue_official_percentage': 100.0, 'mother_tongue_unofficial_percentage': 0.0, 'census_year': 2011}  ... displaying 10 of 58337 total bound parameter sets ...  {'demographics_key': 202135600256, 'dissemination_area': 35600256, 'population': 511, 'median_age': 26.0, 'total_dwellings': 120, 'average_household_size': 4.3, 'median_household_income': 81000.0, 'mother_tongue_official_percentage': 32.0, 'mother_tongue_unofficial_percentage': 68.0, 'census_year': 2021}, {'demographics_key': 202135600238, 'dissemination_area': 35600238, 'population': 409, 'median_age': 19.6, 'total_dwellings': 90, 'average_household_size': 4.4, 'median_household_income': 67500.0, 'mother_tongue_official_percentage': 76.83, 'mother_tongue_unofficial_percentage': 23.17, 'census_year': 2021})]
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
