# %%
import pandas as pd

# %%
#getting data from the preprocessed csv file for 2022
df_2021=pd.read_csv('census_2021.csv')
df_2021= df_2021.drop(columns = ['Unnamed: 0'])
df_2021
# Out:
#        demographics_key  dissemination_area  population  average_age  \
# 0          202135010159            35010159       533.0         45.8
# 1          202135010160            35010160       485.0         45.2
# 2          202135010161            35010161       402.0         44.5
# 3          202135010162            35010162       383.0         50.9
# 4          202135010163            35010163       519.0         45.1
# ...                 ...                 ...         ...          ...
# 20463      202135600224            35600224         NaN          NaN
# 20464      202135600237            35600237         NaN          NaN
# 20465      202135600256            35600256       511.0         30.3
# 20466      202135600218            35600218        16.0          NaN
# 20467      202135600238            35600238       409.0         24.1
#
#        median_age  total_dwellings  average_household_size  \
# 0            50.4            210.0                     2.6
# 1            50.0            200.0                     2.4
# 2            44.8            160.0                     2.5
# 3            57.2            150.0                     2.2
# 4            48.8            210.0                     2.4
# ...           ...              ...                     ...
# 20463         NaN              NaN                     NaN
# 20464         NaN              NaN                     NaN
# 20465        26.0            120.0                     4.3
# 20466         NaN              NaN                     NaN
# 20467        19.6             90.0                     4.4
#
#        median_household_income  mother_tongue_official_percentage  \
# 0                      87000.0                              95.28
# 1                      88000.0                              94.85
# 2                      77000.0                              96.25
# 3                      73500.0                              98.67
# 4                      84000.0                              94.17
# ...                        ...                                ...
# 20463                      NaN                                NaN
# 20464                      NaN                                NaN
# 20465                  81000.0                              32.00
# 20466                      NaN                                NaN
# 20467                  67500.0                              76.83
#
#        mother_tongue_unofficial_percentage  census_year
# 0                                     4.72         2021
# 1                                     5.15         2021
# 2                                     3.75         2021
# 3                                     1.33         2021
# 4                                     5.83         2021
# ...                                    ...          ...
# 20463                                  NaN         2021
# 20464                                  NaN         2021
# 20465                                68.00         2021
# 20466                                  NaN         2021
# 20467                                23.17         2021
#
# [20468 rows x 11 columns]

# %%
#getting the data fromt the preprocessed csv file for 2016
df_2016=pd.read_csv('census_2016.csv')
df_2016= df_2016.drop(columns = ['Unnamed: 0'])
df_2016.dissemination_area=df_2016.dissemination_area.astype('int64')
df_2016
# Out:
#        demographics_key  dissemination_area  population  average_age  \
# 0          2.016350e+11            35010159       517.0         45.9
# 1          2.016350e+11            35010160       509.0         43.5
# 2          2.016350e+11            35010161       388.0         43.7
# 3          2.016350e+11            35010162       376.0         52.7
# 4          2.016350e+11            35010163       501.0         43.9
# ...                 ...                 ...         ...          ...
# 20155      2.016356e+11            35600237       276.0         28.8
# 20156      2.016356e+11            35600256       511.0         29.1
# 20157      2.016356e+11            35600218        22.0          NaN
# 20158      2.016356e+11            35600241         0.0          NaN
# 20159      2.016356e+11            35600238       421.0         25.1
#
#        median_age  total_dwellings  average_household_size  \
# 0            52.5            210.0                     2.5
# 1            47.1            200.0                     2.6
# 2            48.2            150.0                     2.6
# 3            57.5            155.0                     2.2
# 4            47.5            205.0                     2.4
# ...           ...              ...                     ...
# 20155        24.2             85.0                     3.4
# 20156        25.9            100.0                     4.8
# 20157         NaN              NaN                     NaN
# 20158         NaN              NaN                     NaN
# 20159        21.4             85.0                     4.7
#
#        median_household_income  mother_tongue_official_percentage  \
# 0                      31659.0                             100.00
# 1                      32981.0                             100.00
# 2                      31040.0                              98.72
# 3                      29760.0                             100.00
# 4                      35200.0                             100.00
# ...                        ...                                ...
# 20155                  20736.0                              98.18
# 20156                  25664.0                              98.04
# 20157                      NaN                                NaN
# 20158                      NaN                                NaN
# 20159                  17744.0                              98.81
#
#        mother_tongue_unofficial_percentage  census_year
# 0                                     0.00       2016.0
# 1                                     0.00       2016.0
# 2                                     1.28       2016.0
# 3                                     0.00       2016.0
# 4                                     0.00       2016.0
# ...                                    ...          ...
# 20155                                 1.82       2016.0
# 20156                                 1.96       2016.0
# 20157                                  NaN       2016.0
# 20158                                  NaN       2016.0
# 20159                                 1.19       2016.0
#
# [20160 rows x 11 columns]

# %%
#getting the data fromt the preprocessed csv file for 2011
df_2011=pd.read_csv('census_2011.csv')
df_2011= df_2011.drop(columns = ['Unnamed: 0'])
df_2011
# Out:
#        demographics_key  dissemination_area  population  average_age  \
# 0          201135010155            35010155       486.0          NaN
# 1          201135010156            35010156       477.0          NaN
# 2          201135010157            35010157       501.0          NaN
# 3          201135010158            35010158       520.0          NaN
# 4          201135010159            35010159       502.0          NaN
# ...                 ...                 ...         ...          ...
# 19959      201135600399            35600399         0.0          NaN
# 19960      201135600400            35600400         0.0          NaN
# 19961      201135600401            35600401       483.0          NaN
# 19962      201135600402            35600402       556.0          NaN
# 19963      201135600403            35600403         0.0          NaN
#
#        median_age  total_dwellings  average_household_size  \
# 0            47.0            190.0                     2.6
# 1            45.7            200.0                     2.4
# 2            45.8            195.0                     2.6
# 3            46.9            210.0                     2.5
# 4            48.9            205.0                     2.5
# ...           ...              ...                     ...
# 19959         NaN              NaN                     NaN
# 19960         NaN              NaN                     NaN
# 19961        51.4            195.0                     2.5
# 19962         NaN              NaN                     NaN
# 19963         NaN              NaN                     NaN
#
#        median_household_income  mother_tongue_official_percentage  \
# 0                          NaN                             100.00
# 1                          NaN                             100.00
# 2                          NaN                             100.00
# 3                          NaN                             100.00
# 4                          NaN                              99.01
# ...                        ...                                ...
# 19959                      NaN                                NaN
# 19960                      NaN                                NaN
# 19961                      NaN                             100.00
# 19962                      NaN                                NaN
# 19963                      NaN                                NaN
#
#        mother_tongue_unofficial_percentage  census_year
# 0                                     0.00         2011
# 1                                     0.00         2011
# 2                                     0.00         2011
# 3                                     0.00         2011
# 4                                     0.99         2011
# ...                                    ...          ...
# 19959                                  NaN         2011
# 19960                                  NaN         2011
# 19961                                 0.00         2011
# 19962                                  NaN         2011
# 19963                                  NaN         2011
#
# [19964 rows x 11 columns]

# %%
#copy the median_household_income from the next year
df_2011= df_2011.drop(columns = ['median_household_income'])
df_2011=df_2011.merge(df_2016[['dissemination_area', 'median_household_income']], on = 'dissemination_area', how = 'left')
#reordering the rows to match the other dataframes

#list(df_2011)
df_2011=df_2011[['demographics_key', 'dissemination_area','population','average_age','median_age',
                'total_dwellings','average_household_size','median_household_income',
                'mother_tongue_official_percentage','mother_tongue_unofficial_percentage','census_year']]
df_2011
# Out:
#        demographics_key  dissemination_area  population  average_age  \
# 0          201135010155            35010155       486.0          NaN
# 1          201135010156            35010156       477.0          NaN
# 2          201135010157            35010157       501.0          NaN
# 3          201135010158            35010158       520.0          NaN
# 4          201135010159            35010159       502.0          NaN
# ...                 ...                 ...         ...          ...
# 19959      201135600399            35600399         0.0          NaN
# 19960      201135600400            35600400         0.0          NaN
# 19961      201135600401            35600401       483.0          NaN
# 19962      201135600402            35600402       556.0          NaN
# 19963      201135600403            35600403         0.0          NaN
#
#        median_age  total_dwellings  average_household_size  \
# 0            47.0            190.0                     2.6
# 1            45.7            200.0                     2.4
# 2            45.8            195.0                     2.6
# 3            46.9            210.0                     2.5
# 4            48.9            205.0                     2.5
# ...           ...              ...                     ...
# 19959         NaN              NaN                     NaN
# 19960         NaN              NaN                     NaN
# 19961        51.4            195.0                     2.5
# 19962         NaN              NaN                     NaN
# 19963         NaN              NaN                     NaN
#
#        median_household_income  mother_tongue_official_percentage  \
# 0                      27712.0                             100.00
# 1                      26688.0                             100.00
# 2                      31200.0                             100.00
# 3                      32384.0                             100.00
# 4                      31659.0                              99.01
# ...                        ...                                ...
# 19959                      NaN                                NaN
# 19960                      NaN                                NaN
# 19961                  39936.0                             100.00
# 19962                  31584.0                                NaN
# 19963                      NaN                                NaN
#
#        mother_tongue_unofficial_percentage  census_year
# 0                                     0.00         2011
# 1                                     0.00         2011
# 2                                     0.00         2011
# 3                                     0.00         2011
# 4                                     0.99         2011
# ...                                    ...          ...
# 19959                                  NaN         2011
# 19960                                  NaN         2011
# 19961                                 0.00         2011
# 19962                                  NaN         2011
# 19963                                  NaN         2011
#
# [19964 rows x 11 columns]

# %%
#combine the three census years together into one dataframe
frames = [df_2011, df_2016, df_2021]
result = pd.concat(frames)
result
# Out:
#        demographics_key  dissemination_area  population  average_age  \
# 0          2.011350e+11            35010155       486.0          NaN
# 1          2.011350e+11            35010156       477.0          NaN
# 2          2.011350e+11            35010157       501.0          NaN
# 3          2.011350e+11            35010158       520.0          NaN
# 4          2.011350e+11            35010159       502.0          NaN
# ...                 ...                 ...         ...          ...
# 20463      2.021356e+11            35600224         NaN          NaN
# 20464      2.021356e+11            35600237         NaN          NaN
# 20465      2.021356e+11            35600256       511.0         30.3
# 20466      2.021356e+11            35600218        16.0          NaN
# 20467      2.021356e+11            35600238       409.0         24.1
#
#        median_age  total_dwellings  average_household_size  \
# 0            47.0            190.0                     2.6
# 1            45.7            200.0                     2.4
# 2            45.8            195.0                     2.6
# 3            46.9            210.0                     2.5
# 4            48.9            205.0                     2.5
# ...           ...              ...                     ...
# 20463         NaN              NaN                     NaN
# 20464         NaN              NaN                     NaN
# 20465        26.0            120.0                     4.3
# 20466         NaN              NaN                     NaN
# 20467        19.6             90.0                     4.4
#
#        median_household_income  mother_tongue_official_percentage  \
# 0                      27712.0                             100.00
# 1                      26688.0                             100.00
# 2                      31200.0                             100.00
# 3                      32384.0                             100.00
# 4                      31659.0                              99.01
# ...                        ...                                ...
# 20463                      NaN                                NaN
# 20464                      NaN                                NaN
# 20465                  81000.0                              32.00
# 20466                      NaN                                NaN
# 20467                  67500.0                              76.83
#
#        mother_tongue_unofficial_percentage  census_year
# 0                                     0.00       2011.0
# 1                                     0.00       2011.0
# 2                                     0.00       2011.0
# 3                                     0.00       2011.0
# 4                                     0.99       2011.0
# ...                                    ...          ...
# 20463                                  NaN       2021.0
# 20464                                  NaN       2021.0
# 20465                                68.00       2021.0
# 20466                                  NaN       2021.0
# 20467                                23.17       2021.0
#
# [60592 rows x 11 columns]

# %%
#Removed the average age column as the average age was not reported in the 2011 or 2016 census profiles
result=result.drop(columns=['average_age'])
#removed the rows where the population was null and converted it into an integer
result=result.dropna(subset=['population']).reset_index(drop = True) 
result.population=result.population.astype('int64')
#convert date to an integer
result.census_year=result.census_year.astype('int64')
#print the resulting table
result
# Out:
#        demographics_key  dissemination_area  population  median_age  \
# 0          2.011350e+11            35010155         486        47.0
# 1          2.011350e+11            35010156         477        45.7
# 2          2.011350e+11            35010157         501        45.8
# 3          2.011350e+11            35010158         520        46.9
# 4          2.011350e+11            35010159         502        48.9
# ...                 ...                 ...         ...         ...
# 60448      2.021356e+11            35600222        1060        22.4
# 60449      2.021356e+11            35600223           0         NaN
# 60450      2.021356e+11            35600256         511        26.0
# 60451      2.021356e+11            35600218          16         NaN
# 60452      2.021356e+11            35600238         409        19.6
#
#        total_dwellings  average_household_size  median_household_income  \
# 0                190.0                     2.6                  27712.0
# 1                200.0                     2.4                  26688.0
# 2                195.0                     2.6                  31200.0
# 3                210.0                     2.5                  32384.0
# 4                205.0                     2.5                  31659.0
# ...                ...                     ...                      ...
# 60448            230.0                     4.6                  67000.0
# 60449              NaN                     NaN                      NaN
# 60450            120.0                     4.3                  81000.0
# 60451              NaN                     NaN                      NaN
# 60452             90.0                     4.4                  67500.0
#
#        mother_tongue_official_percentage  mother_tongue_unofficial_percentage  \
# 0                                 100.00                                 0.00
# 1                                 100.00                                 0.00
# 2                                 100.00                                 0.00
# 3                                 100.00                                 0.00
# 4                                  99.01                                 0.99
# ...                                  ...                                  ...
# 60448                              35.38                                64.62
# 60449                                NaN                                  NaN
# 60450                              32.00                                68.00
# 60451                                NaN                                  NaN
# 60452                              76.83                                23.17
#
#        census_year
# 0             2011
# 1             2011
# 2             2011
# 3             2011
# 4             2011
# ...            ...
# 60448         2021
# 60449         2021
# 60450         2021
# 60451         2021
# 60452         2021
#
# [60453 rows x 10 columns]

# %%
#uncomment the following line of code if psycopg2 or sqlalchemy not installed locally
#!pip install psycopg2
#!pip install sqlalchemy
import psycopg2
import sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\emi_m\anaconda3\lib\site-packages (1.4.39)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\emi_m\anaconda3\lib\site-packages (from sqlalchemy) (1.1.1)

# %%
#Using postgres 13
#format: postgresql+psycopg2://username:password@host_address/database_name
engine = sqlalchemy.create_engine('postgresql+psycopg2://postgres:CSI4142@localhost:5432/fire_hazard')
result.to_sql(name='demographics_dimension', con=engine,if_exists='append', index=False)
# Out:
# 453
